# %% [markdown]
# # 使用pandas读取csv文件

# %%
import pandas as pd
Dataset=pd.read_csv("G:\DataSet\iris_dataset\iris.csv")
Dataset
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %% [markdown]
# # 读取特定的列

# %%
Dataset=pd.read_csv("G:\DataSet\iris_dataset\iris.csv",usecols=['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width','Species'])

# %%
Dataset
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Dataset的类型为DataFrame

# %%
type(Dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 对某一列求和

# %%
sum(Dataset['Petal.Length'])
# Out:
# 563.7000000000004

# %% [markdown]
# # 跳行读取

# %%
dataSet = pd.read_csv("G:\DataSet\iris_dataset\iris.csv",skiprows=[0], 

                          names=['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species'])

# %%
dataSet
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # DataFrame转为列表list

# %%
dataSet = pd.read_csv("G:\DataSet\iris_dataset\iris.csv",skiprows=[0], 

                          names=['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species'])

# %%
dataSet=dataSet.values.tolist()

# %%
dataSet
# Out:
# [[5.1, 3.5, 1.4, 0.2, 'setosa'],
#  [4.9, 3.0, 1.4, 0.2, 'setosa'],
#  [4.7, 3.2, 1.3, 0.2, 'setosa'],
#  [4.6, 3.1, 1.5, 0.2, 'setosa'],
#  [5.0, 3.6, 1.4, 0.2, 'setosa'],
#  [5.4, 3.9, 1.7, 0.4, 'setosa'],
#  [4.6, 3.4, 1.4, 0.3, 'setosa'],
#  [5.0, 3.4, 1.5, 0.2, 'setosa'],
#  [4.4, 2.9, 1.4, 0.2, 'setosa'],
#  [4.9, 3.1, 1.5, 0.1, 'setosa'],
#  [5.4, 3.7, 1.5, 0.2, 'setosa'],
#  [4.8, 3.4, 1.6, 0.2, 'setosa'],
#  [4.8, 3.0, 1.4, 0.1, 'setosa'],
#  [4.3, 3.0, 1.1, 0.1, 'setosa'],
#  [5.8, 4.0, 1.2, 0.2, 'setosa'],
#  [5.7, 4.4, 1.5, 0.4, 'setosa'],
#  [5.4, 3.9, 1.3, 0.4, 'setosa'],
#  [5.1, 3.5, 1.4, 0.3, 'setosa'],
#  [5.7, 3.8, 1.7, 0.3, 'setosa'],
#  [5.1, 3.8, 1.5, 0.3, 'setosa'],
#  [5.4, 3.4, 1.7, 0.2, 'setosa'],
#  [5.1, 3.7, 1.5, 0.4, 'setosa'],
#  [4.6, 3.6, 1.0, 0.2, 'setosa'],
#  [5.1, 3.3, 1.7, 0.5, 'setosa'],
#  [4.8, 3.4, 1.9, 0.2, 'setosa'],
#  [5.0, 3.0, 1.6, 0.2, 'setosa'],
#  [5.0, 3.4, 1.6, 0.4, 'setosa'],
#  [5.2, 3.5, 1.5, 0.2, 'setosa'],
# ...
